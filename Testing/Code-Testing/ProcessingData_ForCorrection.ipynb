# %% [markdown]
# # Converting Files For Processing and Updating

# %%
import numpy as np
import pandas as pd
from importlib.util import spec_from_file_location, module_from_spec
import pathlib
import re
import DLCsupport as dlcs
import xrommtools as xtc

module_path = r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\Code-Testing\data-converters.py"
spec = spec_from_file_location("dc", module_path)
dc = module_from_spec(spec)
spec.loader.exec_module(dc)

module_path = r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\Code-Testing\xrommtools.py"
spec = spec_from_file_location("xt", module_path)
xt = module_from_spec(spec)
spec.loader.exec_module(xt)
# Out:
# Loading DLC 3.0.0rc13...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)

# %% [markdown]
# #### David Bowie Trial 1

# %%
# JPG TO AVI
dc.jpg_stack_to_avi(
    input_folder=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial1\Cam2"),
    output_path=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial1\Cam2.avi"),
    fps=500
)

# %%
# DLC TO XMALAB
xtc.dlc_to_xma(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial1\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam1DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial1\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam2DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
'NoUpdateModel',
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial1")

# %% [markdown]
# #### David Bowie Trial 2

# %%
# JPG TO AVI
dc.jpg_stack_to_avi(
    input_folder=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial2\Cam1"),
    output_path=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial2\Cam1.avi"),
    fps=500
)
# Out:
# {'output_path': 'C:\\Users\\Salle-Cineradio\\Documents\\MachineLearning\\BirdSongs-MNHN\\Testing\\ProcessingData\\DavidBowie\\Trial2\\Cam1.avi',
#  'frames_written': 6001,
#  'fps': 500,
#  'codec': 'MJPG',
#  'width': 768,
#  'height': 768}

# %%
# DLC TO XMALAB
xtc.dlc_to_xma(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial2\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam1DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial2\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam2DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
'NoUpdateModel',
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial2")
# Out:
# c:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\Code-Testing\xrommtools.py:322: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Cranium_Left_Anterior_cam1_X', 'Cranium_Left_Anterior_cam1_Y',
#        'Cranium_Left_Anterior_cam2_X', 'Cranium_Left_Anterior_cam2_Y',
#        'Cranium_Left_Middle_cam1_X', 'Cranium_Left_Middle_cam1_Y',
#        'Cranium_Left_Middle_cam2_X', 'Cranium_Left_Middle_cam2_Y',
#        'Cranium_Right_Middle_cam1_X', 'Cranium_Right_Middle_cam1_Y',
#        'Cranium_Right_Middle_cam2_X', 'Cranium_Right_Middle_cam2_Y',
#        'Cranium_Right_Posterior_cam1_X', 'Cranium_Right_Posterior_cam1_Y',
#        'Cranium_Right_Posterior_cam2_X', 'Cranium_Right_Posterior_cam2_Y',
#        'Beak_Mandible_Left_Posterior_cam1_X',
#        'Beak_Mandible_Left_Posterior_cam1_Y',
# ...

# %% [markdown]
# #### David Bowie Trial 3

# %%
# JPG TO AVI
dc.jpg_stack_to_avi(
    input_folder=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial3\Cam2"),
    output_path=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial3\Cam2.avi"),
    fps=500
)
# Out:
# {'output_path': 'C:\\Users\\Salle-Cineradio\\Documents\\MachineLearning\\BirdSongs-MNHN\\Testing\\ProcessingData\\DavidBowie\\Trial3\\Cam2.avi',
#  'frames_written': 6001,
#  'fps': 500,
#  'codec': 'MJPG',
#  'width': 768,
#  'height': 768}

# %%
# DLC TO XMALAB
xtc.dlc_to_xma(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial3\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam1DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial3\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam2DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
'NoUpdateModel',
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial3")

# %% [markdown]
# #### David Bowie Trial 4

# %%
# JPG TO AVI
dc.jpg_stack_to_avi(
    input_folder=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial4\Cam2"),
    output_path=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial4\Cam2.avi"),
    fps=500
)
# Out:
# {'output_path': 'C:\\Users\\Salle-Cineradio\\Documents\\MachineLearning\\BirdSongs-MNHN\\Testing\\ProcessingData\\DavidBowie\\Trial4\\Cam2.avi',
#  'frames_written': 6001,
#  'fps': 500,
#  'codec': 'MJPG',
#  'width': 768,
#  'height': 768}

# %%
# DLC TO XMALAB
xtc.dlc_to_xma(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial4\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam1DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial4\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam2DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
'NoUpdateModel',
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial4")

# %% [markdown]
# #### David Bowie Trial 5

# %%
# JPG TO AVI
dc.jpg_stack_to_avi(
    input_folder=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial5\Cam2"),
    output_path=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial5\Cam2.avi"),
    fps=500
)
# JPG TO AVI
dc.jpg_stack_to_avi(
    input_folder=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial5\Cam1"),
    output_path=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial5\Cam1.avi"),
    fps=500
)
# Out:
# {'output_path': 'C:\\Users\\Salle-Cineradio\\Documents\\MachineLearning\\BirdSongs-MNHN\\Testing\\ProcessingData\\DavidBowie\\Trial5\\Cam1.avi',
#  'frames_written': 6001,
#  'fps': 500,
#  'codec': 'MJPG',
#  'width': 768,
#  'height': 768}

# %%
# DLC TO XMALAB
xtc.dlc_to_xma(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial5\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam1DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial5\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam2DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
'NoUpdateModel',
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial5")

# %% [markdown]
# #### David Bowie Trial 6

# %%
# JPG TO AVI
dc.jpg_stack_to_avi(
    input_folder=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial6\Cam2"),
    output_path=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial6\Cam2.avi"),
    fps=500
)
# JPG TO AVI
dc.jpg_stack_to_avi(
    input_folder=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial6\Cam1"),
    output_path=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial6\Cam1.avi"),
    fps=500
)
# Out:
# {'output_path': 'C:\\Users\\Salle-Cineradio\\Documents\\MachineLearning\\BirdSongs-MNHN\\Testing\\ProcessingData\\DavidBowie\\Trial6\\Cam1.avi',
#  'frames_written': 6001,
#  'fps': 500,
#  'codec': 'MJPG',
#  'width': 768,
#  'height': 768}

# %%
# DLC TO XMALAB
xtc.dlc_to_xma(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial6\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam1DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial6\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam2DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
'NoUpdateModel',
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial6")

# %% [markdown]
# #### David Bowie Trial 7

# %%
# JPG TO AVI
dc.jpg_stack_to_avi(
    input_folder=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial7\Cam2"),
    output_path=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial7\Cam2.avi"),
    fps=500
)
# JPG TO AVI
dc.jpg_stack_to_avi(
    input_folder=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial7\Cam1"),
    output_path=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial7\Cam1.avi"),
    fps=500
)
# Out:
# {'output_path': 'C:\\Users\\Salle-Cineradio\\Documents\\MachineLearning\\BirdSongs-MNHN\\Testing\\ProcessingData\\DavidBowie\\Trial7\\Cam1.avi',
#  'frames_written': 6001,
#  'fps': 500,
#  'codec': 'MJPG',
#  'width': 768,
#  'height': 768}

# %%
# DLC TO XMALAB
xtc.dlc_to_xma(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial7\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam1DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial7\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam2DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
'NoUpdateModel',
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial7")

# %% [markdown]
# #### David Bowie Trial 8

# %%
# JPG TO AVI
dc.jpg_stack_to_avi(
    input_folder=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial8\Cam2"),
    output_path=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial8\Cam2.avi"),
    fps=500
)
# JPG TO AVI
dc.jpg_stack_to_avi(
    input_folder=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial8\Cam1"),
    output_path=pathlib.Path(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial8\Cam1.avi"),
    fps=500
)
# Out:
# {'output_path': 'C:\\Users\\Salle-Cineradio\\Documents\\MachineLearning\\BirdSongs-MNHN\\Testing\\ProcessingData\\DavidBowie\\Trial8\\Cam1.avi',
#  'frames_written': 6001,
#  'fps': 500,
#  'codec': 'MJPG',
#  'width': 768,
#  'height': 768}

# %%
# DLC TO XMALAB
xtc.dlc_to_xma(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial8\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam1DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial8\post_processed_data_CanariMay22-trainset95shuffle1_200\Cam2DLC_Resnet50_CanariMay22shuffle1_snapshot_200.csv",
'NoUpdateModel',
r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial8")

# %%
corrected_data = pd.read_csv(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\ProcessingData\DavidBowie\Trial8\active_updates\dino\data\corrections_autosave.csv")
corrected_data
# Out:
#      frame_id camera                      bodypart  x_corrected  y_corrected
# 0        2816   cam1  Beak_Mandibile_Left_Anterior        314.0        283.0
# 1        2816   cam1  Beak_Mandible_Left_Posterior        317.0        276.0
# 2        2816   cam1  Beak_Mandible_Right_Anterior        301.0        286.0
# 3        2816   cam1    Beak_Maxilla_Left_Anterior        319.0        293.0
# 4        2816   cam1   Beak_Maxilla_Left_Posterior        324.0        292.0
# ..        ...    ...                           ...          ...          ...
# 701      5348   cam2                 Keel_Inferior        492.0        508.0
# 702      5348   cam2         Pelvis_Right_Inferior        585.0        498.0
# 703      5348   cam2         Pelvis_Right_Superior        571.0        481.0
# 704      5348   cam2              Superior_Trachea        428.0        354.0
# 705      5348   cam2          Tongue_Lower_Palette        397.0        322.0
#
# [706 rows x 5 columns]

# %% [markdown]
# ### Retraining Models

# %%
wide = (
    corrected_data.pivot(
        index=["frame_id", "camera"],
        columns="bodypart",
        values=["x_corrected", "y_corrected"]
    )
)

wide.columns = [
    f"{bp}_{coord.replace('_corrected','')}"
    for coord, bp in wide.columns
]

wide = wide.reset_index()
display(wide)
# Out:
#     frame_id camera  Beak_Mandibile_Left_Anterior_x  \
# 0       2816   cam1                           314.0
# 1       2816   cam2                           321.0
# 2       2894   cam1                           314.0
# 3       2894   cam2                           323.0
# 4       3158   cam1                           327.0
# 5       3158   cam2                           326.0
# 6       3705   cam1                           329.0
# 7       3705   cam2                           327.0
# 8       3902   cam1                           329.0
# 9       3902   cam2                           328.0
# 10      4055   cam1                           342.0
# 11      4055   cam2                           330.0
# 12      4116   cam1                           343.0
# 13      4116   cam2                           327.0
# 14      4204   cam1                           342.0
# 15      4204   cam2                           316.0
# 16      4206   cam1                           342.0
# ...
