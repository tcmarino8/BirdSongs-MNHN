# %% [markdown]
# # Load in Tabular Data and Check Indexing

# %%
import pandas as pd

# %%
dataframe = pd.read_csv(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\DeepLabCut\Endive\TrainingData_T42\LabeledDataEndive42.csv")
dataframe['FrameNum'] = [i for i in range(len(dataframe))]

# %%
dataframe.to_csv(r"C:\Users\Salle-Cineradio\Documents\MachineLearning\BirdSongs-MNHN\Testing\DeepLabCut\Endive\TrainingData_T42\LabeledDataEndive42_FrameNums.csv")

# %%
dataframe
# Out:
#       Tongue_Marker_cam1_X  Tongue_Marker_cam1_Y  Tongue_Marker_cam2_X  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 5996                   NaN                   NaN                   NaN
# 5997                   NaN                   NaN                   NaN
# 5998                   NaN                   NaN                   NaN
# 5999                   NaN                   NaN                   NaN
# 6000                   NaN                   NaN                   NaN
#
#       Tongue_Marker_cam2_Y  Glottis_Marker_cam1_X  Glottis_Marker_cam1_Y  \
# 0                      NaN                    NaN                    NaN
# 1                      NaN                    NaN                    NaN
# 2                      NaN                    NaN                    NaN
# 3                      NaN                    NaN                    NaN
# 4                      NaN                    NaN                    NaN
# ...                    ...                    ...                    ...
# 5996                   NaN                    NaN                    NaN
# 5997                   NaN                    NaN                    NaN
# 5998                   NaN                    NaN                    NaN
# 5999                   NaN                    NaN                    NaN
# 6000                   NaN                    NaN                    NaN
#
#       Glottis_Marker_cam2_X  Glottis_Marker_cam2_Y  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                       NaN                    NaN
# 4                       NaN                    NaN
# ...                     ...                    ...
# 5996                    NaN                    NaN
# 5997                    NaN                    NaN
# 5998                    NaN                    NaN
# 5999                    NaN                    NaN
# 6000                    NaN                    NaN
#
#       Cranium_Marker_Anterior_cam1_X  Cranium_Marker_Anterior_cam1_Y  ...  \
# 0                                NaN                             NaN  ...
# 1                                NaN                             NaN  ...
# 2                                NaN                             NaN  ...
# 3                                NaN                             NaN  ...
# 4                                NaN                             NaN  ...
# ...                              ...                             ...  ...
# 5996                             NaN                             NaN  ...
# 5997                             NaN                             NaN  ...
# 5998                             NaN                             NaN  ...
# 5999                             NaN                             NaN  ...
# 6000                             NaN                             NaN  ...
#
#       Pelvis_Marker_Left_Superior_cam2_Y  Pelvis_Marker_Left_Inferior_cam1_X  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# ...                                  ...                                 ...
# 5996                                 NaN                                 NaN
# 5997                                 NaN                                 NaN
# 5998                                 NaN                                 NaN
# 5999                                 NaN                                 NaN
# 6000                                 NaN                                 NaN
#
#       Pelvis_Marker_Left_Inferior_cam1_Y  Pelvis_Marker_Left_Inferior_cam2_X  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# ...                                  ...                                 ...
# 5996                                 NaN                                 NaN
# 5997                                 NaN                                 NaN
# 5998                                 NaN                                 NaN
# 5999                                 NaN                                 NaN
# 6000                                 NaN                                 NaN
#
#       Pelvis_Marker_Left_Inferior_cam2_Y  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 5996                                 NaN
# 5997                                 NaN
# 5998                                 NaN
# 5999                                 NaN
# 6000                                 NaN
#
#       Maxilla_Marker_Right_Anterior_cam1_X  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 5996                                   NaN
# 5997                                   NaN
# 5998                                   NaN
# 5999                                   NaN
# 6000                                   NaN
#
#       Maxilla_Marker_Right_Anterior_cam1_Y  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 5996                                   NaN
# 5997                                   NaN
# 5998                                   NaN
# 5999                                   NaN
# 6000                                   NaN
#
#       Maxilla_Marker_Right_Anterior_cam2_X  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 5996                                   NaN
# 5997                                   NaN
# 5998                                   NaN
# 5999                                   NaN
# 6000                                   NaN
#
#       Maxilla_Marker_Right_Anterior_cam2_Y  FrameNum
# 0                                      NaN         0
# 1                                      NaN         1
# 2                                      NaN         2
# 3                                      NaN         3
# 4                                      NaN         4
# ...                                    ...       ...
# 5996                                   NaN      5996
# 5997                                   NaN      5997
# 5998                                   NaN      5998
# 5999                                   NaN      5999
# 6000                                   NaN      6000
#
# [6001 rows x 97 columns]
